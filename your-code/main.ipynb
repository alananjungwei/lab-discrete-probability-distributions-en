# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!
#
# *Notes:*
#
# - Solve the questions with python.
#
# - Round the final answer to three decimal places.

# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Bernoulli's Distribution
#
# In a basket containing 100 fruits, there are 60 apples and 40 oranges.
#
# A fruit is picked randomly from the basket.
#
# 1. **What is the probability that the fruit is apple?**
# 1. **What is the probability that it is an orange?**

# %%
"""
Calculate:
p = probability that the fruit is an apple 
q = probability that the fruit is an orange
"""
p = 60/100
q = 40/100
print("The probability that the fruit is an apple is:", p)
print("The probability that the fruit is an orange is:", q)
# Out:
# The probability that the fruit is an apple is: 0.6
# The probability that the fruit is an orange is: 0.4

# %% [markdown]
# Now we take a random sample of 20 fruits from the basket. After each fruit is taken, a new fruit of the same type is replaced in the basket. Therefore, every time we are taking 1 fruit from 100 fruits.
#
# 1. **What is the probability that the first 5 fruits are all apples?**
#
# 1. **What is the probability that the first 5 fruits are all apples and the next 15 fruits are all oranges?**
#
# You can include the `p` and `q` probabilities you previous calculated in your solution.

# %%
# What is the probability that the first 5 fruits are all apples?

# First 5 fruits are all apples, since we are replacing a fruit every time
print(f"The probability that the first 5 fruits are all apples is: {(p**5):.3f}")
# First 5 apples and the next 15 orange
print(f"The probability of first 5 apples followed by 15 oranges is: {((p**5)*(q**15)):.8f}")
# Out:
# The probability that the first 5 fruits are all apples is: 0.078
# The probability of first 5 apples followed by 15 oranges is: 0.00000008

# %% [markdown]
# ## Binomial Distribution
#
# Similar to the above problem, this time again we randomly sample 20 fruits.
#
# **What is the probability that this time the sample contains 5 apples and 15 oranges?**
#
# Please note that this time the order of the fruits being picked does not matter.

# %%
import math

# %%
# your solution here

# We first compute the total possible scenarios:
total = math.comb(100, 20)
print(f"The total number of combinations is: {total}")

# favourable, 5 apples out of 60 and 15 oranges out of 40 
apples_five = math.comb(60, 5)
oranges_fifteen = math.comb(40, 15)
favourable = apples_five * oranges_fifteen 
print(f"The number of favorable outcome is: {favourable}")

# now probability 
probability = favourable/total
print(f"The probability of 5 apples and 15 oranges is: {probability:.6f}")
# Out:
# The total number of combinations is: 535983370403809682970
# The number of favorable outcome is: 219691204727484672
# The probability of 5 apples and 15 oranges is: 0.000410

# %% [markdown]
# In the lesson we also discussed CDF (cumulative distribution function). In the context of the above problem, **what is the probability that less than 5 fruits picked are apples?**
#
# Write the formula and calculate the probability below.

# %%
import scipy.stats as stats

# %%
# your code here
p_lessthanfive = stats.binom.cdf(4, 20, 0.6)
# less than 5, n = 20 for 20 draws, 0.6 for probability of getting an apple
print(f"The probability that less than 5 fruits picked are apples is: {p_lessthanfive:.6f}")
# Out:
# The probability that less than 5 fruits picked are apples is: 0.000317

# %% [markdown]
# <!-- **Plot the PDF (probability distributiom function) for the above binomial distribution.** -->
#
# **Plot the Probability Mass Function (PMF) for the above binomial distribution.**
#
# *Hint: The range of x in a binomial distribution is from `0` to `n`.*

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# your code here
# Please label the axes and give a title to the plot 
n = 20
p = 0.6
x = np.arange(0, n+1)
pmf = stats.binom.pmf(x, n, p)

plt.bar(x, pmf)
plt.xlabel("Number of Apples")
plt.ylabel("Probability")
plt.title("Binomial Distribution PMF (n = 20, p = 0.6)")
plt.show()

# %% [markdown]
# ## Poisson Distribution
#
# In this challenge you are required to use the Math library in python to solve the problems.
#
# In the UEFA champions league tournament, the average number of goals scored in a match is 2.3.
#
# **What is the probability that the number of goals scored in a match is 5?**
#
# *Hint: Use the exp() in the math library*
#
# And to calculate the factorial, you can use the following code:
#
# ```python
# import math
# math.factorial(n) # n is the number you want to find the factorial of
# ```

# %%
# your code here 
# average is 2.3. that is our lambda
lam = 2.3
# we want to find number of goals 5
k = 5 
goal_prob = ((lam**k) * math.exp(-lam))/(math.factorial(k))
print(f"The probability that the numnber of goals scored in a match is 5 is: {goal_prob:.4f}")
# Out:
# The probability that the numnber of goals scored in a match is 5 is: 0.0538

# %% [markdown]
# **Draw a poisson probability distribution plot for the number of goals to be between 0 to 10.**

# %%
from scipy.stats import poisson

# %%
# your code here
# Please label the axes and give a title to the plot 
x = np.arange(0, 11) # so that 10 is in the picture
pmf = poisson.pmf(x, lam)
plt.bar(x, pmf)
plt.xlabel("Number of Goals")
plt.ylabel("Probability")
plt.title("Poisson Distribution (lambda = 2.3)")
plt.show()
